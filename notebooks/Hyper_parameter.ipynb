# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import subplots_adjust
import pandas as pd

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### 1) Basic Function

# %%
# MAE
x = ["30","64","128","256","512"]
y1 = [0.898,0.690,0.572,0.527,0.545]
lower_error1 = [0.0332,0.03192,0.03138,0.02396,0.087225]
upper_error1 = [0.03254,0.03908,0.02722,0.02554,0.188975]

asymmetric_error1 = [lower_error1, upper_error1]

fig, ax0 = plt.subplots(nrows=1, sharex=True,figsize = [6,4])

ax0.errorbar(x, y1, capsize=2,yerr=asymmetric_error1, c = "coral",fmt='o',ls = 'solid',label = "2_reuse")

ax0.set_title('')
ax0.set_xlabel("Number of Basis Functions", size = 14,fontname="Arial")
ax0.set_ylabel("MAE (kcal/mol)", size = 14,fontname="Arial")
plt.ylim(0.3,1)
plt.yticks(fontsize = 12)
ax0.set_xticklabels(x,size = 12,fontname="Arial")
ax0.set_xticklabels(x,size = 12,fontname="Arial");
#plt.savefig("parm_1_basisfunction_mae.pdf",dpi = 300);

# %% [markdown]
# ### 2) Share/Distinct Weights

# %%
# MAE
x = ["shared","distinct"]
y1 = [0.5524,0.5029,0.5102,0.526,0.5428]
y2 = [0.4579,0.4522,0.3976,0.4151,0.4113]


fig, ax0 = plt.subplots(nrows=1, sharex=True,figsize = [3,4])

ax0.boxplot([y1,y2],whis="range")

ax0.set_title('')

ax0.set_xlabel("Interaction Block Weights", size = 14,fontname="Arial")
ax0.set_ylabel("MAE (kcal/mol)", size = 14,fontname="Arial")
plt.ylim(0.3,0.6)
plt.yticks(fontsize = 12)
ax0.set_xticklabels(x,size = 12,fontname="Arial")
ax0.set_xticklabels(x,size = 12,fontname="Arial")

subplots_adjust(left = 0.3);
#plt.savefig("parm_2_retainreuseweights_mae.pdf",dpi = 300);

# %% [markdown]
# ### 3) Umax and gap

# %%
x = ["3","4","5","6","8","10","20"]
y1 = [0.3491,0.3694,0.3659,0.3745,0.3724,0.3611,0.3819]
y2 = [0.3724,0.3770,0.3886,0.3916,0.4041,0.4052,0.3931]

fig,ax0 = plt.subplots(figsize = [4.5,4])
plt.plot(x,y1,color = "coral", label = "Δμ=0.1", marker = "o")
plt.plot(x,y2, color = "green",label = "Δμ=0.2", marker = "o")
ax0.set_xlabel("$μ_{max} $", size = 14,fontname="Arial")
ax0.set_ylabel("MAE (kcal/mol)", size = 14,fontname="Arial")
#plt.ylim(0.3,0.5)
plt.yticks(fontsize = 12)
ax0.set_xticklabels(x,size = 12,fontname="Arial")
ax0.set_xticklabels(x,size = 12,fontname="Arial")
ax0.legend(loc = "upper left", fontsize = 10)
fig.tight_layout();
#plt.savefig("parm_3_umaxgap_mae.pdf",dpi = 300);

# %% [markdown]
# ### 4) Umax and Number of Refinement block

# %%
x = ["2","3","4","5","6","7","8"]
y1 = [0.4243,0.3831,0.3466,0.3393,0.3426,0.2899,0.3182]
y2 = [0.4241,0.3842,0.3740,0.3707,0.3461,0.3391,0.3478]
y3 = [0.4212,0.3986,0.3753,0.3567,0.3464,0.3274,0.3359]
y4 = [0.4143,0.4133,0.3940,0.3482,0.3505,0.3489,0.3520]
y5 = [0.4268,0.3953,0.3964,0.3741,0.3509,0.3416,0.3216]
y6 = [0.4045,0.3975,0.3703,0.3576,0.3458,0.3512,0.3443]
y7 = [0.4133,0.4086,0.3923,0.3798,0.3629,0.3590,0.3574]

fig,ax0 = plt.subplots(figsize = [6,4])
plt.plot(x,y1, label = "$μ_{max} =3$", marker = "o", color = "coral")
plt.plot(x,y2, label = "$μ_{max} =4$", marker = "o", color = "green")
plt.plot(x,y3, label = "$μ_{max} =5$", marker = "o", color = "pink")
plt.plot(x,y4, label = "$μ_{max} =6$", marker = "o", color = "cornflowerblue")
plt.plot(x,y5, label = "$μ_{max} =8$", marker = "o", color = "orange")
plt.plot(x,y6, label = "$μ_{max} =10$", marker = "o", color = "lightgreen")
plt.plot(x,y7, label = "$μ_{max} =20$", marker = "o", color = "grey")
ax0.set_xlabel("Number of Interaction Blocks", size = 14,fontname="Arial")
ax0.set_ylabel("MAE (kcal/mol)", size = 14,fontname="Arial")
#plt.ylim(0.3,0.5)
plt.yticks(fontsize = 12)
ax0.set_xticklabels(x,size = 12,fontname="Arial")
ax0.set_xticklabels(x,size = 12,fontname="Arial")
ax0.legend(loc = "lower left", fontsize = 10);
#plt.savefig("parm_4_umaxrefinementblocks_mae.pdf",dpi = 300);

# %% [markdown]
# ### 5) SSoftmax and tanh

# %%
x = ["2","3","4","5","6","7","8"]
y1 = [0.4243,0.3831,0.3466,0.3393,0.3426,0.2899,0.3182]
y2 = [0.4241,0.3842,0.3740,0.3707,0.3461,0.3391,0.3478]
fig,ax0 = plt.subplots(figsize = [4.5,4])
plt.plot(x,y1, label = "shifted soft_plus", marker = "o", color = "coral")
plt.plot(x,y2, label = "tanh", marker = "o", color = "green")
ax0.set_xlabel("Number of Interaction Blocks", size = 14,fontname="Arial")
ax0.set_ylabel("MAE (kcal/mol)", size = 14,fontname="Arial")
#plt.ylim(0.3,0.5)
plt.yticks(fontsize = 12)
ax0.set_xticklabels(x,size = 12,fontname="Arial")
ax0.set_xticklabels(x,size = 12,fontname="Arial")
ax0.legend(loc = "lower left", fontsize = 10)
fig.tight_layout();
#plt.savefig("parm_5_activationfunction_mae.pdf",dpi = 300);

# %% [markdown]
# ### 6) Training Schedule

# %%
x = ["Cyclic","Decay"]

y1 = [0.9307,0.8885, 0.9050, 0.9017, 0.8649]
y2 = [1.2597,1.2614, 1.2103, 1.2253, 1.2735]


fig, ax0 = plt.subplots(nrows=1, sharex=True,figsize = [3,4])

ax0.boxplot([y1,y2],whis="range")

ax0.set_title('')

ax0.set_xlabel("Training Schedule", size = 14,fontname="Arial")
ax0.set_ylabel("MAE (kcal/mol)", size = 14,fontname="Arial")
plt.ylim(0.8,1.3)
plt.yticks(fontsize = 12)
ax0.set_xticklabels(x,size = 12,fontname="Arial")
ax0.set_xticklabels(x,size = 12,fontname="Arial")
#ax0.legend(fontsize = 13);
#fig.tight_layout()
subplots_adjust(left = 0.3);
#plt.savefig("parm_6_trainingschedule_mae.pdf",dpi = 300);

# %% [markdown]
# ### 7) Training Curve

# %%
df = pd.read_csv("training_schedule_30_3_20.csv")
df.head()
# Out:
#    step     epoch  Cyclic_train  Cyclic_val  Cyclic_test  Decay_train  \
# 0  1000  1.010101        6.7301      6.9180       6.9037       9.6435
# 1  2000  2.020202        6.1441      5.3369       5.4094       6.4690
# 2  3000  3.030303        7.5730      5.3774       5.4360       5.0966
# 3  4000  4.040404        5.7685      4.5097       4.5143       4.2225
# 4  5000  5.050505        3.6477      4.1133       4.0084       4.6671
#
#    Decay_val  Decay_test
# 0     8.8780      9.1305
# 1     7.2069      7.5018
# 2     7.2248      7.3927
# 3     4.7875      4.8560
# 4     4.6141      4.6386

# %%
x = df["epoch"]
y_train = df["Cyclic_train"]
y_val = df["Cyclic_val"]
y_train_1 = df["Decay_train"]
y_val_1 = df["Decay_val"]

# %%
fig,ax0 = plt.subplots(figsize = [5,4])

plt.plot(x, y_train, color = "red",label = "Cyclic_train")
plt.plot(x, y_val, color = "lightcoral", label = "Cyclic_val")
plt.plot(x, y_train_1, color = "green",label = "Decay_train")
plt.plot(x, y_val_1, color = "lightgreen",label = "Decay_val")
plt.xlim(0,400);
plt.ylim(0,10);
ax0.set_xlabel("Number of Epochs", size = 14,fontname="Arial")
ax0.set_ylabel("MAE (kcal/mol)", size = 14,fontname="Arial")
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
ax0.legend(loc = "upper right", fontsize = 12);
plt.savefig("parm_7_learningcurve_mae_resize.pdf",dpi = 300);

# %%
99000 +1500
# Out:
# 100500

# %% [markdown]
# ### 8) Learning Curve

# %%
import numpy  as np

# %%
x = [1000, 5000, 10000, 15000, 25000, 50000, 75000, 100500]
#x = [str(num) for num in x]
DTNN_7ib_MAE = [3.87, 1.62, 1.14, 0.92, 0.69, 0.46, 0.38, 0.34]
DTNN_7ib_MAE_1 = [0.12, 0.04, 0.03, 0.03, 0.02, 0.02, 0.01, 0.01]
DTNN_7ib_RMSE = [6.30, 2.89, 2.25, 2.00, 1.58, 1.15, 0.94, 0.86]
DTNN_7ib_RMSE_1 = [0.29, 0.15, 0.14, 0.14, 0.13, 0.11, 0.07, 0.07]

TL_QM9_MAE = [6.31, 2.67, 2.10, 1.85, 1.49, 1.01, 0.82, 0.79]
TL_QM9_MAE_1 = [1.64, 0.06, 0.11, 0.08, 0.03, 0.03, 0.02, 0.01]
TL_QM9_RMSE = [9.06, 4.21, 3.39, 3.10, 2.51, 1.83, 1.53, 1.45]
TL_QM9_RMSE_1 = [1.81, 0.07, 0.11, 0.08, 0.08, 0.06, 0.03, 0.05]

# %%
def draw_graph(x, y, y_1, error, error_1, error_name, save = False, out = None):
    #x = ["1k","5k","10k","15k","25k","50k","75k","100k"] 
    fig = plt.figure(figsize=[6,4.8])
    plt.errorbar(x,y,error, marker='o', color = "coral", label = "DTNN_7ib")
    plt.errorbar(x,y_1,error_1, marker='o',color = "green", label = "TL_QM9$_\mathrm{M}$")
    plt.yticks(size = 12)
    plt.xticks([5000, 15000, 25000, 50000, 75000, 100500], ["5k","15k","25k","50k","75k","100k"],size = 12)
    plt.legend(fontsize = 12)
    #plt.yticks([0.50, 0.55, 0.6,0.65, 0.70],size = 12)
    plt.xlabel("Number of Training Examples", size = 14,fontname="Arial")
    plt.ylabel(error_name + " (kcal/mol)", size = 14,fontname="Arial")
    if save:
        plt.savefig(out,dpi = 300)

# %%
draw_graph(x, DTNN_7ib_MAE, TL_QM9_MAE, DTNN_7ib_MAE_1, TL_QM9_MAE_1, "MAE", save = True, out = "Learning_curves_ourmodels.pdf")

# %%
x = [25000, 50000, 100000]
x = [int(x) for x in x]
x = np.log10(x)

DTNN = [1.04, 0.94, 0.84]
DTNN_1 = [0.02, 0.01, 0.02]
DTNN_7ib_MAE  = [0.69, 0.46,0.34]
DTNN_7ib_MAE_1 = [0.02, 0.02, 0.01]
schnet = [0.59,0.34]
# DTNN
y_1 = [1.04, 0.94, 0.84]
# DTNN_7ib
y = [0.69, 0.46,0.34]
# TL_QM9M
y_2 = [1.49, 1.01, 0.79]

y = np.log10(y)
y_1 = np.log10(y_1)
y_2 = np.log10(y_2)
fig = plt.figure(figsize=[6,4.8])
plt.errorbar(x,y_1, marker='o', label = "DTNN")
plt.errorbar(x,y,marker='o', label = "DTNN_7ib")
plt.errorbar(x,y_2, marker='o', label = "TL_QM9$_\mathrm{M}$")
plt.yticks([-0.5, -0.4, -0.3, -0.2, -0.1, 0.0, 0.1, 0.2],[round(10 ** -0.5,1), round(10 ** -0.4,1),
                                                          round(10 ** -0.3,1), round(10 ** -0.2,1),
                                                          round(10 ** -0.1,1), round(10 ** -0.0,1),
                                                          round(10 ** 0.1,1), round(10 ** 0.2,1)],size = 12)
plt.xticks([4.4, 4.7, 5.0], ["25k", "50k", "100k"], size = 12)
plt.legend(fontsize = 12)
#plt.yticks([0.50, 0.55, 0.6,0.65, 0.70],size = 12)
plt.xlabel("Number of Training Examples", size = 14,fontname="Arial")
plt.ylabel("MAE (kcal/mol)", size = 14,fontname="Arial")
plt.savefig("log_log_three_models.pdf", dpi = 300);
